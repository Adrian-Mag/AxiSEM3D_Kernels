# %%
from axikernels.core.handlers import element_output
from axikernels.core.kernels import objective_function, kernel
from axikernels.aux import mesher
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Sensitivity kernel based on 1D background Earth model
#
# In this notebook we will compute a simple P wave sensitivity kernel (banana doughnut).
#
# ## Run forward simulation
#
# The first step is to set up a forward simulation with element output:
#
# 1. We use an already existing mesh suitable for 50s period simulations based on the prem isotropic and elastic model (prem_iso_elastic_50s.e).
# 2. For the inparam.nr.yaml we just need to make sure to use a constant nr=5 in the whole domain since we are doing a 1D simulation (this is where the speed-up happens compared to other full 3D wave solvers).
# 3. For the source we can use whatever we like. In this case I used an explosion source.
# 4. Finally, in the inparam.output.yaml we will put 1 element group for the mantle, 1 for the outer core, and 1 for the inner core. Even though the simulation runs using 16 GLL points on each element, we will output only 9 to save some disk space.
# 5. Run axisem3d (see at the end details about computational costs)
#
# After running the simulation, we create an *ElementOutput* object to hold the simulation information.

# %%
forward_simulation = element_output.ElementOutput(path_to_element_output='data/1D_KERNEL_EXAMPLE/output/elements')

# %% [markdown]
# ## Run Backward simulation
#
# The next step depends on what kind of objective function we want. The most popoular objective function is:
# $$
# \chi = \frac{1}{2}\mathcal{T}^2
# $$
# where $\mathcal{T}$ is the cross-correlation time shift between some observed displacement $\bm{u}(m;\bm{r}_0,t)$ (based on the real or a synthetic earth model $m$) and the forward displacement $\bm{u}_0(m_0;\bm{r}_0,t)$ at the same receiver location $\bm{r}_0$ (computed at the reference Earth $m_0$). We will use this objective as well:

# %%
time_shift_objective = objective_function.XObjectiveFunction(forward_simulation)

# %% [markdown]
# The backward field is computed over the same mesh as the forward field, the only difference is the source, which for the backward simulation is given by:
# $$
# f^{\dagger} = \frac{\mathcal{T} W[\dot{\bm{u}}] }{\left| W[\dot{\bm{u}}] \right|^2_2}
# $$
# Here $\dot{\bm{u}}$ is the time derivative of the forward displacement field evaluated at the location of the receiver. $W$ is the operator that represents "time windowing", which is needed if we want to isolate a certain phase. Mathematically, the backward field would be computed by solving the same wave equation as for the forward simulation but backwards in time and with $f^{\dagger}$ replacing the earthquake source.
#
# The *.compute_backward_field()* method of our XObjectiveFunction instance will:
# 1. Create a new simulation directory for the backward simulation
# 2. Create an adjoint source and save it in the input directory of the backward simulation directory as three STF functions.
# 3. Run the backward simulation
#
# This method needs the following inputs:
# 1. Time shift $\mathcal{T}$ in seconds
# 2. The location of the reciever (in form [radius, latitude, longitude]) in meters and degrees.
# 3. Left and right time limits (in seconds) of the window containing the desired phase
# 4. The number of cores to be used for the AxiSEM3D simulation
# 5. The channel on which we observe the forward wavefield at the receiver.
#
# In this case we will isolate a P400P wave

# %%
receiver_point = [6371000, 0, 20]
window = [270-25, 270+25]

# %%
# %matplotlib inline
time_shift_objective.compute_backward_field(tau=2, receiver_point=receiver_point,
                                             window=window, cores=16, channel = 'UZ')
# Out:
# Files copied successfully!
# Loading and interpolating: 100%|██████████| 1/1 [00:00<00:00, 674.54point/s]
# Directory created: /disks/data/PhD/AxiSEM3D_Kernels/examples/data/backward_1D_KERNEL_EXAMPLE_P220P/input/STF
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#       A            |i .|'''.|'||''''E'||    ||'  ____'||''|.
#      |||   ... ...... ||..  ' ||  .   |||  |||   ` // ||   ||
#     |  ||   '|..'  ||  ''|||. ||''|   |'|..'||    //  ||    ||
#    .''''|.   .x.   ||      '||||      | 'M' ||    \\  ||    ||
#   .|.  .||..|  ||..||.|'...|S.||....|.|. | .||.    3' D|...|'
#   .............................................   //
#                                                  /'     v 1.0
#
#   Copyright (c) 2019 Kuangdai Leng & friends, MIT License
#   Source, docs and issues: github.com/kuangdai/AxiSEM-3D
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# ========================== Exodus Mesh =========================
# Overview________________________________________________________
#   Exodus file           =  prem_iso_elastic_50s.e
#   mesh CS               =  spherical
#   model name            =  prem_iso_elastic
#   isotropic             =  true
#   attenuation           =  false
#   storage type          =  element_nodes
#   # discontinuities     =  13
# Mesh geometry___________________________________________________
#   # elements            =  6400
#   # nodes               =  6589
#   range of r-axis       =  [0, 6.371e+06]
#   range of θ-axis       =  [0, 3.14159]
# Global variables________________________________________________
#   dist_tolerance        =  9.4
#   dt (nPol = 1)         =  0.829412
#   min_edge_length       =  9400
#   minimum_period        =  48.8647
#   radius                =  6.371e+06
#   crdsys                =  spherical
#   model                 =  prem_iso_elastic
# Element geometry________________________________________________
#   linear                :  768
#   semi-spherical        :  256
#   spherical             :  5376
# Element medium__________________________________________________
#   fluid                 :  768
#   solid                 :  5632
# Material properties_____________________________________________
#   RHO                   ∈  [2600, 13088.5]
#   VP                    ∈  [5800, 13716.6]
#   VS                    ∈  [0, 7265.97]
# Side sets_______________________________________________________
#   r1                    :  256 sides
#   solid_fluid_boundary  :  256 sides
#   t0                    :  120 sides
# Miscellaneous___________________________________________________
#   ellipticity curve     :  2398 knots
# ----------------------------------------------------------------
# Mesh generation command line:
# >> python -m salvus_mesh_lite.interface AxiSEM -o prem_iso_elastic_50s.e
#    --overwrite_file --basic.model prem_iso_elastic.bm --basic.period 50
# ================================================================
#
#
# ============================ Geodesy ===========================
# model in Cartesian     =  false
# surface radius         =  6.371e+06
# solid surface radius   =  6.371e+06
# bottom radius          =  0
# a reference geographic location on the positive z-axis
#   latitude             =  0
#   longitude            =  20
#   radius               =  6.371e+06
# flattening on surface  =  0.00335281
# flattening at discontinuities___________________________________
#   f = 0.00335281    at  6.371e+06
#   f = 0.00334821    at  6.356e+06
#   f = 0.00334533    at  6.3466e+06
#   f = 0.00332839    at  6.291e+06
#   f = 0.00328615    at  6.151e+06
#   f = 0.003233      at  5.971e+06
#   f = 0.00317513    at  5.771e+06
#   f = 0.00315503    at  5.701e+06
#   f = 0.00312593    at  5.6e+06
#   f = 0.00257612    at  3.63e+06
#   f = 0.0025605     at  3.48e+06
#   f = 0.00243364    at  1.2215e+06
#   f = 0.00242322    at  0
# * Correcting for ellipticity in latitude-θ conversions.
# ================================================================
#
#
# ====================== Absorbing Boundary ======================
# user-specified boundaries  =  [RIGHT, BOTTOM]
# * The mesh contains none of these boundaries.
# ================================================================
#
#
# ============================ Nr(s,z) ===========================
# type   =  CONSTANT
# value  =  5
# ================================================================
#
#
# ====================== Computed Nr on Mesh =====================
# min Nr  =  5
# max Nr  =  5
# ave Nr  =  5
# sum Nr  =  32945
# * Nr has been limited by inplane resolution.
# * Nr has been rounded up to FFTW lucky numbers.
# ================================================================
#
#
# =========================== 3D Models ==========================
# * No 3D models in this simulation.
# ================================================================
#
#
# =========================== Time Step ==========================
# Δt determined by mesh  =  0.1671
#    Courant number      =  0.7
#    location (r,θ)      =  [6.35118e+06, 3.12318]
# Δt enforced by user    =  NONE
# Δt to be used          =  0.1671
# ================================================================
#
#
# ========================== Attenuation =========================
# * Attenuation is turned off.
# ================================================================
#
#
# ===================== Computational Domain =====================
# GLL points______________________________________________________
#   FluidPoint$Mass1D              =  12593
#   SolidPoint$Mass1D              =  91074
#   Σ                              =  103667
# Spectral elements_______________________________________________
#   FluidElement$Acoustic1D        =  768
#   SolidElement$Isotropic1D       =  5632
#   Σ                              =  6400
# Axial boundary__________________________________________________
#   Solid                          =  387
#   Fluid                          =  98
#   Σ                              =  485
# Absorbing boundary______________________________________________
#   Σ                              =  0
# Fluid surface boundary__________________________________________
#   Σ                              =  0
# Solid-fluid boundary____________________________________________
#   SolidFluidCoupling1D           =  514
#   Σ                              =  514
# Domain decomposition____________________________________________
#   # sub-domains (nproc)          =  16
#   # rank-to-rank communications  =  31
# ================================================================
#
#
# ============================ Sources ===========================
# pointZ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   * This source is used to determine the reference
#     geographic location on the mesh axis.
#   Location______________________________________________________
#     latitude            =  0
#     longitude           =  20
#     depth               =  0 (below solid surface)
#     radial geometry     =  undulated
#   Source mechanism______________________________________________
#     force vector        =  1
#                            0
#                            0
#   Source-time function__________________________________________
#     class name          =  StreamSTF
#     Ascii file          =  STF/UZ.txt
#     1st (time, value)   =  (306.629, -0.121921)
#     last (time, value)  =  (353.417, 0.162048)
#     [min, max] values   =  [-0.400248, 0.415692]
#     padding             =  [-0.121921, 0.162048]
# pointR ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   Location______________________________________________________
#     latitude            =  0
#     longitude           =  20
#     depth               =  0 (below solid surface)
#     ellipticity correction  =  true
#     radial geometry     =  undulated
#   Source mechanism______________________________________________
#     force vector        =  0
#                            1
#                            0
#   Source-time function__________________________________________
#     class name          =  StreamSTF
#     Ascii file          =  STF/UR.txt
#     1st (time, value)   =  (306.629, 0)
#     last (time, value)  =  (353.417, 0)
#     [min, max] values   =  [0, 0]
#     padding             =  [0, 0]
# pointT ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   Location______________________________________________________
#     latitude            =  0
#     longitude           =  20
#     depth               =  0 (below solid surface)
#     ellipticity correction  =  true
#     radial geometry     =  undulated
#   Source mechanism______________________________________________
#     force vector        =  0
#                            0
#                            1
#   Source-time function__________________________________________
#     class name          =  StreamSTF
#     Ascii file          =  STF/UT.txt
#     1st (time, value)   =  (306.629, 0)
#     last (time, value)  =  (353.417, 0)
#     [min, max] values   =  [0, 0]
#     padding             =  [0, 0]
# ================================================================
#
#
# ======================== Simulation Time =======================
# Δt of simulation          =  0.1671
# t0 determined by sources  =  306.629
# t1 specified by user      =  600
# [t0, t1] used by solver   =  [306.628, 600.056]
# # time steps              =  1757
# ================================================================
#
#
# ======================== Station groups ========================
# Station_grid ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   Locations_____________________________________________________
#     station location file      =  STA_10DEG_GRID.txt
#     coordinates in file        =  (latitude, longitude, depth)
#     ellipticity correction     =  true
#     depth below solid surface  =  true
#     radial geometry            =  undulated
#   Wavefields____________________________________________________
#     output coordinate system   =  RTZ
#     medium type                =  solid
#     user-specified channels    =  [U, G, S]
#     standardized channels      =  [U1, U2, U3, G11, G12, G13, G21, G22, G23, G31, G32, G33, S11, S22, S33, S23, S31, S12]
#   Temporal______________________________________________________
#     sampling period
#       user-specified           =  1.671
#       rounded to Δt            =  1.671
#     # time steps per sample    =  10
#     time window                =  [306.628, 600.223]
#   File options__________________________________________________
#     output file format         =  NetCDF (serial)
#     buffer size                =  50000
#     flush file                 =  true
#   Dimensions____________________________________________________
#     # stations                 =  631
#     # channels                 =  18
#     # time steps               =  176
# ================================================================
#
#
# ======================== Element groups ========================
# mantle ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   Elements______________________________________________________
#     horizontal range          =  [0, 3.14159]
#     vertical range            =  [3.48e+06, 6.371e+06]
#   Inplane sampling______________________________________________
#     edge dimension            =  both
#     # elements found          =  4800
#     GLL points on one edge    =  [0, 2, 4]
#     # GLL points per element  =  9
#   Azimuthal sampling____________________________________________
#     * Recording all Fourier series coefficients.
#       grid space for Nr-storage  =  1
#   Wavefields____________________________________________________
#     output coordinate system  =  RTZ
#     medium type               =  solid
#     user-specified channels   =  [U, G, S]
#     standardized channels     =  [U1, U2, U3, G11, G12, G13, G21, G22, G23, G31, G32, G33, S11, S22, S33, S23, S31, S12]
#   Temporal______________________________________________________
#     sampling period
#       user-specified          =  1.671
#       rounded to Δt           =  1.671
#     # time steps per sample   =  10
#     time window               =  [306.628, 600.223]
#   File options__________________________________________________
#     buffer size               =  1000
#     flush file                =  true
#   Dimensions____________________________________________________
#     # elements                =  4800
#     # Fourier series          =  variable
#     # GLL points              =  9
#     # channels                =  18
#     # time steps              =  176
# ================================================================
#
#
#
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TTTTTTTTTTTTTTTTTTT NEWMARK TIME LOOP STARTS TTTTTTTTTTTTTTTTTTT
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
#
#
#   wave propagation time / sec  =  323.171
#   time step / num total steps  =  100 / 1757 (5%)
#   elapsed wall-clock time / h  =  9.23792e-05
#   est. remaining w-c time / h  =  0.00153072
#   est. aggregate w-c time / h  =  0.0016231
#
#   wave propagation time / sec  =  339.881
#   time step / num total steps  =  200 / 1757 (11%)
#   elapsed wall-clock time / h  =  0.000181235
#   est. remaining w-c time / h  =  0.00141092
#   est. aggregate w-c time / h  =  0.00159215
#
#   wave propagation time / sec  =  356.591
#   time step / num total steps  =  300 / 1757 (17%)
#   elapsed wall-clock time / h  =  0.000272173
#   est. remaining w-c time / h  =  0.00132186
#   est. aggregate w-c time / h  =  0.00159403
#
#   wave propagation time / sec  =  373.301
#   time step / num total steps  =  400 / 1757 (22%)
#   elapsed wall-clock time / h  =  0.000362272
#   est. remaining w-c time / h  =  0.00122901
#   est. aggregate w-c time / h  =  0.00159128
#
#   wave propagation time / sec  =  390.011
#   time step / num total steps  =  500 / 1757 (28%)
#   elapsed wall-clock time / h  =  0.000451979
#   est. remaining w-c time / h  =  0.00113627
#   est. aggregate w-c time / h  =  0.00158825
#
#   wave propagation time / sec  =  406.721
#   time step / num total steps  =  600 / 1757 (34%)
#   elapsed wall-clock time / h  =  0.000560016
#   est. remaining w-c time / h  =  0.0010799
#   est. aggregate w-c time / h  =  0.00163991
#
#   wave propagation time / sec  =  423.431
#   time step / num total steps  =  700 / 1757 (39%)
#   elapsed wall-clock time / h  =  0.00067935
#   est. remaining w-c time / h  =  0.00102582
#   est. aggregate w-c time / h  =  0.00170517
#
#   wave propagation time / sec  =  440.141
#   time step / num total steps  =  800 / 1757 (45%)
#   elapsed wall-clock time / h  =  0.000799967
#   est. remaining w-c time / h  =  0.000956961
#   est. aggregate w-c time / h  =  0.00175693
#
#   wave propagation time / sec  =  456.851
#   time step / num total steps  =  900 / 1757 (51%)
#   elapsed wall-clock time / h  =  0.000917986
#   est. remaining w-c time / h  =  0.000874127
#   est. aggregate w-c time / h  =  0.00179211
#
#   wave propagation time / sec  =  473.561
#   time step / num total steps  =  1000 / 1757 (56%)
#   elapsed wall-clock time / h  =  0.00103742
#   est. remaining w-c time / h  =  0.000785324
#   est. aggregate w-c time / h  =  0.00182274
#
#   wave propagation time / sec  =  490.271
#   time step / num total steps  =  1100 / 1757 (62%)
#   elapsed wall-clock time / h  =  0.00114754
#   est. remaining w-c time / h  =  0.000685396
#   est. aggregate w-c time / h  =  0.00183294
#
#   wave propagation time / sec  =  506.981
#   time step / num total steps  =  1200 / 1757 (68%)
#   elapsed wall-clock time / h  =  0.00123846
#   est. remaining w-c time / h  =  0.000574854
#   est. aggregate w-c time / h  =  0.00181332
#
#   wave propagation time / sec  =  523.691
#   time step / num total steps  =  1300 / 1757 (73%)
#   elapsed wall-clock time / h  =  0.00133133
#   est. remaining w-c time / h  =  0.000468014
#   est. aggregate w-c time / h  =  0.00179935
#
#   wave propagation time / sec  =  540.401
#   time step / num total steps  =  1400 / 1757 (79%)
#   elapsed wall-clock time / h  =  0.00142558
#   est. remaining w-c time / h  =  0.000363522
#   est. aggregate w-c time / h  =  0.0017891
#
#   wave propagation time / sec  =  557.111
#   time step / num total steps  =  1500 / 1757 (85%)
#   elapsed wall-clock time / h  =  0.00151862
#   est. remaining w-c time / h  =  0.00026019
#   est. aggregate w-c time / h  =  0.00177881
#
#   wave propagation time / sec  =  573.821
#   time step / num total steps  =  1600 / 1757 (91%)
#   elapsed wall-clock time / h  =  0.00160686
#   est. remaining w-c time / h  =  0.000157673
#   est. aggregate w-c time / h  =  0.00176453
#
#   wave propagation time / sec  =  590.531
#   time step / num total steps  =  1700 / 1757 (96%)
#   elapsed wall-clock time / h  =  0.00169565
#   est. remaining w-c time / h  =  5.68541e-05
#   est. aggregate w-c time / h  =  0.0017525
#
#
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TTTTTTTTTTTTTTTTTT NEWMARK TIME LOOP FINISHES TTTTTTTTTTTTTTTTTT
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
#
# wave propagation time / sec  =  600.223
# total # time steps finished  =  1757
# elapsed wall-clock time / h  =  0.00187828

# %% [markdown]
# Now we should see a new directory called "backward_1D_KERNEL_EXAMPLE". We will load this simulation and use it as an argument together with the foward simulation to form a "Kernel" object. While the XObjectiveFunction class deals with creating the adjoint wavefield, the Kernel class deals with computing the actual kernels.

# %%
backward_simulation = element_output.ElementOutput(path_to_element_output='data/backward_1D_KERNEL_EXAMPLE_P220P/output/elements')
ker = kernel.Kernel(forward_simulation, backward_simulation)

# %% [markdown]
# With the forward and backward data at hand, we can compute volumetric or geometric sensitivity kernels. Volumetric sensitivity kernels can be visualized both on a slice through the Earth, or on a spherical shell centered on the Earth's center.
#
# In the *mesher* module there are two classes that deal with slices and shells. The *SliceMesh* class takes in the following arguments:
# 1. **point1, point2**: these are in the [rad, lat lon] format where radius is in the same units as used in the basemodel (ideal to stick with SI units everywhere) and the latitude and longitude are by default in degree (but passing the argument *degrees=False* will switch to radians). These two points, together with the Earth's center, determine a great circle disk/slice through the Earth on which the kernel will be computed.
# 2. **domains**: this has the form [[rad_min, rad_max, theta_min, theta_max],[rad_min, rad_max, theta_min, theta_max],...]. By default the slice contains the full great circle disk, but if we want, we can restrict it to one or more regions described by a min and max radius, and a min and max angle from point1 in the direction towards point2. Obviously, the kernel can only be computed in regions where we have an output from the simulation. For example, if in the inparam.output.yaml file we specified only the mantle region as an element group, then the kernel will be computed only in that region intersected with the regions specified in the domains argument.
# 3. **resolution**: The mesh points on the slice are placed in a uniform grid of size *resolution* X *resolution*

# %%
source_location = [forward_simulation.Domain_Radius - forward_simulation.source_depth,
                    forward_simulation.source_lat,
                    forward_simulation.source_lon]
receiver_point = [6371000, 0, 40]
domains = [[4000000, 6371000, -np.pi, np.pi]]
slice = mesher.SliceMesh(point1=source_location,
                     point2=receiver_point,
                     domains=domains,
                     resolution=300)

# %% [markdown]
# When the mesh is created, the coordinates of the points found within the specified domains will be saved in the *.points* attribute. Thse points can then be passed to any *.evaluate_...() * method to compute the sensitivity at those points. Currently there are the following volumetric kernel methods:
#
# ---------key-------method------------------
# - 'rho_0': self.evaluate_rho_0,
# - 'lambda': self.evaluate_lambda,
# - 'mu': self.evaluate_mu,
# - 'rho': self.evaluate_rho,
# - 'vp': self.evaluate_vp,
# - 'vs': self.evaluate_vs,
#
# So let's say we want to compute the vp sensitivity kernel on the mesh computed above (decrease the resolution or restrict your domains if you want a faster computation):

# %%
parameter = 'vp'
sensitivity_kernel_slice = ker.evaluate_vp(slice.points)
"""
# or alternatively using:
sensitivity_kernel = ker.kernel_types[parameter](slice.points) """
# Out:
# Loading and interpolating: 100%|██████████| 42488/42488 [00:07<00:00, 5975.59point/s]
# Loading and interpolating: 100%|██████████| 42488/42488 [00:08<00:00, 5141.70point/s]
# '\n# or alternatively using:\nsensitivity_kernel = ker.kernel_types[parameter](slice.points) '

# %% [markdown]
# The resulting sensitivity data can be then passed in the *.plot_on_mesh()* method of the mesh to have it plotted. *high_range* stretches the sensitivity values to show the weaker signals in the kernel. This is often needed since the sensitivity kernels take very large values near the source.

# %%
slice.plot_on_mesh(data=sensitivity_kernel_slice, high_range=0.1)

# %% [markdown]
# Lastly, we can save this data using:

# %%
slice.save_data(data=sensitivity_kernel_slice, filename=parameter+'_P220P')
# Out:
# /disks/data/PhD/AxiSEM3D_Kernels/axikernels/aux/mesher.py:194: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->values] [items->None]
#
#   metadata.to_hdf(filename + '.h5', key='metadata', mode='a')

# %% [markdown]
# The data that has been saved in this manner can be easily plotted later by creating a mesh with the saved file:

# %%
saved_mesh = mesher.SliceMesh('vp_P400P.h5')
saved_mesh.plot_on_mesh(high_range=0.05)

# %% [markdown]
# Alternatively, we can compute the sensitivity kernel on a spherical shell. The *SphereMesh* class produces a spherical fibonacci mesh with 2n points and a radius given by the user

# %%
shell = mesher.SphereMesh(radius=6151000, n=30000, domain=[-20, 20, -20, 60])
shell.plot()

# %% [markdown]
# The points saved in this mesher are simply [lat, lon] in radians, so we must add the radius to obtain the full points.

# %%
points = np.insert(np.array(shell.points), 0, shell.radius, axis=1)
sensitivity_kernel_shell = ker.evaluate_vp(points)
# Out:
# Loading and interpolating: 100%|██████████| 4562/4562 [00:01<00:00, 4521.16point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6641.43point/s]

# %% [markdown]
# Then we can plot the kernel on the shell

# %%
shell.plot_on_mesh(data=sensitivity_kernel_shell)

# %% [markdown]
# And save it

# %%
shell.save_data(data=sensitivity_kernel_shell, filename='shell_vp_P400P')
# Out:
# /disks/data/PhD/AxiSEM3D_Kernels/axikernels/aux/mesher.py:335: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->values] [items->None]
#
#   metadata.to_hdf(filename + '.h5', key='metadata', mode='a')

# %% [markdown]
# And reload it

# %%
new_mesh = mesher.SphereMesh('shell_vp_P400P.h5')
new_mesh.plot_on_mesh(remove_outliers=True, gamma=0.05)

# %%
sensitivity_kernel_shell_400km = ker.evaluate_Kd(shell.points, 5971000)
# Out:
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 4667.21point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6755.58point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 4756.97point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6779.31point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 5096.15point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6735.07point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 4708.57point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6765.52point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 5076.24point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6972.56point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 4634.94point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6724.63point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:01<00:00, 2512.89point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:01<00:00, 4435.16point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 5077.34point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 7079.43point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 4653.62point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:00<00:00, 6650.26point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:01<00:00, 2508.81point/s]
# Loading and interpolating: 100%|██████████| 4562/4562 [00:01<00:00, 4429.19point/s]

# %%
shell.plot_on_mesh(data=sensitivity_kernel_shell_400km)

# %%
shell.save_data(data=sensitivity_kernel_shell_400km, filename='shell_K_dv_P400P')
# Out:
# /disks/data/PhD/AxiSEM3D_Kernels/axikernels/aux/mesher.py:335: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->values] [items->None]
#
#   metadata.to_hdf(filename + '.h5', key='metadata', mode='a')

# %% [markdown]
# ## Simulation costs
#
# ### 1D_KERNEL_EXAMPLE
# - Max RAM usage ~ 12 GB
# - Disk usage ~ 5.8 GB
# - Time ~ 0.0576 CPUh/ (13s on high end cpu)
#
# ### backward_1D_KERNEL_EXAMPLE
# - Max RAM usage ~ 10 GB
# - Disk usage ~ 4.2 GB
# - Time ~ 0.044 CPUh/ (10s on high end cpu)
